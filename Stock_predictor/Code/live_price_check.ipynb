# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# %%
ticker = 'SBIN' #share name code
exchange = 'NSE' # NSE, BOM
url = f'https://www.google.com/finance/quote/{ticker}:{exchange}'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
class1 = 'YMlKec fxKbKc'
price = float(soup.find(class_ = class1).text.strip()[1:].replace(",",""))
print(price)
# Out:
# 814.35

# %%
for i in range(5):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    class1 = 'YMlKec fxKbKc'
    price = float(soup.find(class_ = class1).text.strip()[1:].replace(",",""))
    print(f'{exchange} : {ticker} -> {price}')
    time.sleep(10)
# Out:
# NSE : SBIN -> 814.45
# NSE : SBIN -> 815.0
# NSE : SBIN -> 815.0
# NSE : SBIN -> 814.6
# NSE : SBIN -> 814.35

# %% [markdown]
# ## NSEDownload
# A Python Library to download publicly available data on the NSE website for stocks as pandas dataframe.

# %% [markdown]
# git clone https://github.com/NSEDownload/NSEDownload
#
# pip3 install NSEDownload/dist/*

# %%
import os
os.getcwd()
# Out:
# 'd:\\Study\\Python-Projects\\Stock Predictor'

# %%
from NSEDownload.NSEDownload import scraper
from NSEDownload.NSEDownload import stocks

# %%
# Gets data without adjustment for events
df = get_data(stock_symbol="RELIANCE", start_date='1-8-2024', end_date='6-8-2024')

# %%
df.head()
# Out:
#                             Symbol Series  High Price  Low Price  Open Price  \
# Date
# 2024-06-17T18:30:00.000Z  RELIANCE     EQ      2974.8    2942.70     2974.70
# 2024-06-18T18:30:00.000Z  RELIANCE     EQ      2975.0    2912.00     2975.00
# 2024-06-19T18:30:00.000Z  RELIANCE     EQ      2965.7    2900.20     2918.00
# 2024-06-20T18:30:00.000Z  RELIANCE     EQ      2949.4    2881.15     2947.25
# 2024-06-23T18:30:00.000Z  RELIANCE     EQ      2899.0    2875.00     2891.05
#
#                           Close Price  Last Price  Prev Close Price  \
# Date
# 2024-06-17T18:30:00.000Z      2962.05      2959.9           2955.10
# 2024-06-18T18:30:00.000Z      2917.30      2917.0           2962.05
# 2024-06-19T18:30:00.000Z      2947.40      2949.0           2917.30
# 2024-06-20T18:30:00.000Z      2908.40      2912.0           2947.40
# 2024-06-23T18:30:00.000Z      2882.95      2885.0           2908.40
#
#                           Total Traded Quantity  Total Traded Value  \
# Date
# ...

# %%
df.to_csv('reliance_test.csv')

# %% [markdown]
# ## Getting Historical Data from y! Finance

# %%
print("hello")
# Out:
# hello

# %%
import yfinance as yf
import pandas as pd

# %%
ticker = 'ZOMATO.NS'
data = yf.download(ticker,start = '2024-07-01', end = '2024-07-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-01  199.710007  204.500000  194.559998  203.970001  203.970001
# 2024-07-02  204.000000  209.839996  202.250000  209.089996  209.089996
# 2024-07-03  209.449997  213.949997  205.330002  208.440002  208.440002
# 2024-07-04  208.389999  210.289993  206.699997  207.440002  207.440002
# 2024-07-05  207.000000  208.399994  204.770004  207.570007  207.570007
# 2024-07-08  208.250000  210.000000  206.000000  207.929993  207.929993
# 2024-07-09  207.800003  214.000000  206.610001  212.559998  212.559998
# 2024-07-10  213.000000  213.389999  205.740005  211.369995  211.369995
# 2024-07-11  211.470001  218.949997  211.369995  217.139999  217.139999
# 2024-07-12  219.000000  223.250000  217.050003  222.470001  222.470001
# 2024-07-15  225.000000  232.000000  225.000000  229.149994  229.149994
# 2024-07-16  230.000000  230.350006  215.300003  217.490005  217.490005
# ...

# %%
zomato = yf.Ticker("ZOMATO.NS")

# get all stock info
zomato.info
# Out:
# {'address1': 'Pioneer Square Building',
#  'address2': 'Tower 1 - Ground to 6th Floor Near Golf Course Extension, Sector 62',
#  'city': 'Gurugram',
#  'zip': '122008',
#  'country': 'India',
#  'phone': '91 12 4426 8565',
#  'website': 'https://www.zomato.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
# get historical market data
hist = zomato.history(period="max")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-07-23 00:00:00+05:30  116.000000  138.899994  115.000000  126.000000
# 2021-07-26 00:00:00+05:30  126.349998  143.750000  125.300003  140.649994
# 2021-07-27 00:00:00+05:30  141.699997  147.800003  127.750000  132.899994
# 2021-07-28 00:00:00+05:30  131.000000  135.000000  123.550003  131.199997
# 2021-07-29 00:00:00+05:30  134.949997  144.000000  132.199997  141.550003
# ...                               ...         ...         ...         ...
# 2024-08-06 00:00:00+05:30  265.899994  275.000000  247.199997  249.080002
# 2024-08-07 00:00:00+05:30  261.529999  267.600006  251.809998  265.670013
# 2024-08-08 00:00:00+05:30  265.000000  267.500000  260.000000  265.589996
# 2024-08-09 00:00:00+05:30  267.730011  272.899994  265.549988  267.089996
# 2024-08-12 00:00:00+05:30  263.500000  266.489990  261.350006  263.429993
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
zom_hist = zomato.history(period = "max")
zom_hist.shape
# Out:
# (754, 7)

# %%
type(zom_hist)
# Out:
# pandas.core.frame.DataFrame

# %%
reliance = yf.Ticker("RELIANCE.NS")

# get all stock info
reliance_hist = reliance.history(period = 'max')
reliance_hist.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1996-01-01 00:00:00+05:30  9.268533  9.318267  9.207497  9.302443   52060684
# 1996-01-02 00:00:00+05:30  9.279838  9.325050  9.162285  9.230103   84371654
# 1996-01-03 00:00:00+05:30  9.381563  9.808821  9.279836  9.300181  104661939
# 1996-01-04 00:00:00+05:30  9.212018  9.241405  9.089944  9.214278  108450132
# 1996-01-05 00:00:00+05:30  9.178108  9.178108  9.071860  9.150981   83354233
#
#                            Dividends  Stock Splits
# Date
# 1996-01-01 00:00:00+05:30        0.0           0.0
# 1996-01-02 00:00:00+05:30        0.0           0.0
# 1996-01-03 00:00:00+05:30        0.0           0.0
# 1996-01-04 00:00:00+05:30        0.0           0.0
# 1996-01-05 00:00:00+05:30        0.0           0.0

# %%
reliance_hist.shape
# Out:
# (7185, 7)

# %%
7185/365
# Out:
# 19.684931506849313

# %%
nifty50_list = pd.read_csv('ind_nifty50list.csv')
nifty50_list.head()
# Out:
#                                  Company Name            Industry      Symbol  \
# 0                      Adani Enterprises Ltd.     Metals & Mining    ADANIENT
# 1  Adani Ports and Special Economic Zone Ltd.            Services  ADANIPORTS
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare  APOLLOHOSP
# 3                           Asian Paints Ltd.   Consumer Durables  ASIANPAINT
# 4                              Axis Bank Ltd.  Financial Services    AXISBANK
#
#   Series     ISIN Code
# 0     EQ  INE423A01024
# 1     EQ  INE742F01042
# 2     EQ  INE437A01024
# 3     EQ  INE021A01026
# 4     EQ  INE238A01034

# %%
nifty50_list['Symbol_yf'] = nifty50_list['Symbol'] + '.NS'

# %%
top5list = list(nifty50_list.head()['Symbol_yf'])

# %%
all_vars = {}
for stock in enumerate(top5list):
    # globals()[f"{stock[1].split('.')[0]}"] = yf.Ticker(stock[1])
    # globals()[f"{stock[1].split('.')[0]}_hist"] = globals()[f"{stock[1].split('.')[0]}"].history(period = 'max')
    all_vars[f"{stock[1].split('.')[0]}_hist"] = globals()[f"{stock[1].split('.')[0]}"].history(period = 'max')

# %%
all_vars.keys()
# Out:
# dict_keys(['ADANIENT_hist', 'ADANIPORTS_hist', 'APOLLOHOSP_hist', 'ASIANPAINT_hist', 'AXISBANK_hist'])

# %%
for key in all_vars.keys():
    print(key)
# Out:
# ADANIENT_hist
# ADANIPORTS_hist
# APOLLOHOSP_hist
# ASIANPAINT_hist
# AXISBANK_hist

# %%
list(all_vars.keys())[1]
# Out:
# 'ADANIPORTS_hist'

# %%
all_vars['ADANIPORTS_hist'].head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2007-11-27 00:00:00+05:30  140.130082  188.356668  140.130082  174.525650
# 2007-11-28 00:00:00+05:30  176.527498  179.985256  159.175020  161.058594
# 2007-11-29 00:00:00+05:30  164.698351  166.336238  153.287764  161.422577
# 2007-11-30 00:00:00+05:30  161.968481  174.161608  161.968481  169.065979
# 2007-12-03 00:00:00+05:30  171.022339  180.949736  167.792065  178.347321
#
#                              Volume  Dividends  Stock Splits
# Date
# 2007-11-27 00:00:00+05:30  27262365        0.0           0.0
# 2007-11-28 00:00:00+05:30  21958915        0.0           0.0
# 2007-11-29 00:00:00+05:30  25616715        0.0           0.0
# 2007-11-30 00:00:00+05:30  23047035        0.0           0.0
# 2007-12-03 00:00:00+05:30  14578850        0.0           0.0
